# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fname = "../Canary/sim/pclk.yml"

# %%
import an 
edges, periods, stats = an.period_stats(fname)
stats
# Out:
# Stats(mean=2.5000081724086203e-10, std=3.070702871062789e-12, min=2.3428799999945717e-10, max=2.6256800000293984e-10)

# %%
plt.plot(edges[:-1], periods)
plt.ylim((stats.min, stats.max))
# Out:
# (2.3428799999945717e-10, 2.6256800000293984e-10)

# %%
from ruamel import yaml
y = yaml.safe_load(open(fname, "r"))

# %%
plt.hist(periods - stats.mean)
# Out:
# (array([1.0000e+00, 1.3000e+01, 3.6500e+02, 2.7220e+03, 9.0060e+03,
#         1.4205e+04, 9.9790e+03, 3.2230e+03, 4.5800e+02, 2.6000e+01]),
#  array([-1.57128172e-11, -1.28848172e-11, -1.00568172e-11, -7.22881724e-12,
#         -4.40081724e-12, -1.57281724e-12,  1.25518276e-12,  4.08318276e-12,
#          6.91118276e-12,  9.73918276e-12,  1.25671828e-11]),
#  <BarContainer object of 10 artists>)
