# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import an 
edges, periods, stats = an.period_stats("../Dco/sv/sim/pclk.yml")
stats
# Out:
# Stats(mean=4.999626532448918e-10, std=2.4844096230845324e-11, min=4.0037600000012344e-10, max=5.999999999996216e-10)

# %%
plt.plot(edges[:-1], periods)
plt.ylim((stats.min, stats.max))
# Out:
# (4.0037600000012344e-10, 5.999999999996216e-10)

# %%
fname = "../Dco/sv/sim/pclk.yml"
from ruamel import yaml
y = yaml.safe_load(open(fname, "r"))

# %%
plt.hist(periods - stats.mean)
# Out:
# (array([  19.,  213., 1436., 4711., 8726., 8736., 4529., 1381.,  222.,
#           28.]),
#  array([-9.95866532e-11, -7.96242532e-11, -5.96618532e-11, -3.96994532e-11,
#         -1.97370532e-11,  2.25346755e-13,  2.01877468e-11,  4.01501468e-11,
#          6.01125468e-11,  8.00749468e-11,  1.00037347e-10]),
#  <BarContainer object of 10 artists>)

# %%
len(edges)
# Out:
# 30002
