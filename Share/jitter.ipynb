# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import an 
edges, periods, stats = an.period_stats("../Canary/sim/pclk.yml")
stats
# Out:
# Stats(mean=2.962975924027379e-10, std=3.981545544722718e-12, min=2.8058699999979986e-10, max=3.1339400000075183e-10)

# %%
plt.plot(edges[:-1], periods)
plt.ylim((stats.min, stats.max))
# Out:
# (2.8058699999979986e-10, 3.1339400000075183e-10)

# %%
fname = "../Canary/sim/pclk.yml"
from ruamel import yaml
y = yaml.safe_load(open(fname, "r"))

# %%
plt.hist(periods - stats.mean)
# Out:
# (array([2.300e+01, 4.170e+02, 1.741e+03, 6.659e+03, 1.040e+04, 8.852e+03,
#         4.612e+03, 8.950e+02, 1.440e+02, 6.000e+00]),
#  array([-1.57105924e-11, -1.24298924e-11, -9.14919240e-12, -5.86849240e-12,
#         -2.58779240e-12,  6.92907598e-13,  3.97360760e-12,  7.25430760e-12,
#          1.05350076e-11,  1.38157076e-11,  1.70964076e-11]),
#  <BarContainer object of 10 artists>)
