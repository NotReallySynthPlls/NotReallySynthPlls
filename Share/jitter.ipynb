# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import an 
edges, periods, stats = an.period_stats("../Canary/sim/pclk.yml")

# %%
stats
# Out:
# Stats(mean=2.962958223354766e-10, std=1.8048034632084308e-12, min=2.895299999980416e-10, max=3.048899999995498e-10)

# %%
plt.plot(edges[:-1], periods)
plt.ylim((stats.min, stats.max))
# Out:
# (2.895299999980416e-10, 3.048899999995498e-10)

# %%
fname = "../Canary/sim/pclk.yml"
from ruamel import yaml
y = yaml.safe_load(open(fname, "r"))

# %%
plt.hist(periods)
# Out:
# (array([8.5000e+01, 1.0230e+03, 4.2800e+03, 8.1070e+03, 1.1148e+04,
#         6.1060e+03, 2.8320e+03, 1.5700e+02, 1.0000e+01, 1.0000e+00]),
#  array([2.89530e-10, 2.91066e-10, 2.92602e-10, 2.94138e-10, 2.95674e-10,
#         2.97210e-10, 2.98746e-10, 3.00282e-10, 3.01818e-10, 3.03354e-10,
#         3.04890e-10]),
#  <BarContainer object of 10 artists>)
